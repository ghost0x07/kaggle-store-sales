# %%
# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
import lightgbm as lgbm
import pandas as pd
import os

# %%
loc_pre = os.getenv("LOC_PRE")
loc_pre_test = f"{loc_pre}/test.csv"

# %%
df_test = pd.read_csv(loc_pre_test,index_col=[0])
df_test.head(5)
# Out:
#          store_nbr      family  onpromotion type_x locale locale_name  \
# id
# 3000888          1  AUTOMOTIVE            0    NaN    NaN         NaN
# 3000889          1   BABY CARE            0    NaN    NaN         NaN
# 3000890          1      BEAUTY            2    NaN    NaN         NaN
# 3000891          1   BEVERAGES           20    NaN    NaN         NaN
# 3000892          1       BOOKS            0    NaN    NaN         NaN
#
#         description transferred  dcoilwtico   city      state type_y  cluster  \
# id
# 3000888         NaN         NaN        46.8  Quito  Pichincha      D       13
# 3000889         NaN         NaN        46.8  Quito  Pichincha      D       13
# 3000890         NaN         NaN        46.8  Quito  Pichincha      D       13
# 3000891         NaN         NaN        46.8  Quito  Pichincha      D       13
# 3000892         NaN         NaN        46.8  Quito  Pichincha      D       13
#
#          transactions  year  month  day
# id
# 3000888           NaN  2017      8   16
# 3000889           NaN  2017      8   16
# 3000890           NaN  2017      8   16
# 3000891           NaN  2017      8   16
# 3000892           NaN  2017      8   16

# %%
cat_cols = [name for name,type in df_test.dtypes.items() if type=="object"]
cat_cols
# Out:
# ['family',
#  'type_x',
#  'locale',
#  'locale_name',
#  'description',
#  'transferred',
#  'city',
#  'state',
#  'type_y']

# %%
for col in cat_cols:
    df_test[col] = df_test[col].astype("category")

# %%
model = lgbm.Booster(model_file="./lgbm.pkl")

# %%
df_test
# Out:
#          store_nbr                      family  onpromotion type_x locale  \
# id
# 3000888          1                  AUTOMOTIVE            0    NaN    NaN
# 3000889          1                   BABY CARE            0    NaN    NaN
# 3000890          1                      BEAUTY            2    NaN    NaN
# 3000891          1                   BEVERAGES           20    NaN    NaN
# 3000892          1                       BOOKS            0    NaN    NaN
# ...            ...                         ...          ...    ...    ...
# 3029395          9                     POULTRY            1    NaN    NaN
# 3029396          9              PREPARED FOODS            0    NaN    NaN
# 3029397          9                     PRODUCE            1    NaN    NaN
# 3029398          9  SCHOOL AND OFFICE SUPPLIES            9    NaN    NaN
# 3029399          9                     SEAFOOD            0    NaN    NaN
#
#         locale_name description transferred  dcoilwtico   city      state  \
# id
# 3000888         NaN         NaN         NaN       46.80  Quito  Pichincha
# 3000889         NaN         NaN         NaN       46.80  Quito  Pichincha
# 3000890         NaN         NaN         NaN       46.80  Quito  Pichincha
# 3000891         NaN         NaN         NaN       46.80  Quito  Pichincha
# 3000892         NaN         NaN         NaN       46.80  Quito  Pichincha
# ...             ...         ...         ...         ...    ...        ...
# 3029395         NaN         NaN         NaN       47.26  Quito  Pichincha
# 3029396         NaN         NaN         NaN       47.26  Quito  Pichincha
# 3029397         NaN         NaN         NaN       47.26  Quito  Pichincha
# 3029398         NaN         NaN         NaN       47.26  Quito  Pichincha
# 3029399         NaN         NaN         NaN       47.26  Quito  Pichincha
#
#         type_y  cluster  transactions  year  month  day
# id
# 3000888      D       13           NaN  2017      8   16
# 3000889      D       13           NaN  2017      8   16
# 3000890      D       13           NaN  2017      8   16
# 3000891      D       13           NaN  2017      8   16
# 3000892      D       13           NaN  2017      8   16
# ...        ...      ...           ...   ...    ...  ...
# 3029395      B        6           NaN  2017      8   31
# 3029396      B        6           NaN  2017      8   31
# 3029397      B        6           NaN  2017      8   31
# 3029398      B        6           NaN  2017      8   31
# 3029399      B        6           NaN  2017      8   31
#
# [28512 rows x 17 columns]

# %%
predictions = model.predict(df_test)

# %%
df = pd.DataFrame({"id": df_test.index, "sales": predictions})

# %%
df.to_csv("../submission.csv",index=False)
